# %% [markdown]
# # vixtor : package for solving questions like 3D vector (coded with love ;)
#
# ## [![image.png](attachment:image.png)](https://pypi.org/project/vixtor/)

# %%
# !pip install vixtor
# Out:
# ...
#   Created wheel for vixtor: filename=vixtor-0.0.1-py3-none-any.whl size=4989 sha256=8b062745c0ef0e1d410072543b8ef477d25a94f81956a6727d602b35fb6a12ee
#   Stored in directory: c:\users\vicky\appdata\local\pip\cache\wheels\05\0b\cc\fa4b5e95c8a847f2b66ced6c26b38247b31981ca6de4b2a272
# Successfully built vixtor
# ...

# %%
import vixtor # calls _init_.py file
# Out:
# >>> Available functions are...
#
#
# >>> Made with LOVE and HARDWORK...
#
# 	mod(vector=[2,1,2])
# 	showplane(n=[1, 1, 2])
# 	showline(a=[-1,0,2], b=[4,4,4], u=1)
# 	line(a=[1,2,-4], b=[2,3,6], two_points = False, sno='')
# 	plane(a=[2,5,-3], n=[-2,-3,5], p=[5,3,-3], dis=34, nd = False, three_points = False, sno='')
# 	comp_hcf(x=15, y=80)
# 	distbw2line(a1=[1,2,-4], b1=[2,3,6], a2=[3,3,-5], b2=[2,3,6])
# 	coplanof2line(a1=[-3, 1,5], b1=[-3,1,5], a2=[-1,2,5], b2=[-1,2,5])
# 	angbw2plane(n1=[2,1,-2], d1=5, n2=[2,1,-2], d2=7)
# 	distbwpointandplane(a=[2,5,-3], n=[6,-3,2], d=4)
# 	angbwlineandplane(a=[2,5,-3], b=[3,5,1], n=[6,-3,2], d=4)
#
# ....The moving power of mathematical invention is not
# reasoning but imagination. – A.DEMORGAN

# %%
from vixtor import threeDvector as vix

vix
# Out:
# <module 'vixtor.threeDvector' from 'C:\\Users\\Vicky\\anaconda3\\lib\\site-packages\\vixtor\\threeDvector.py'>

# %%
angle = vix.angbw2plane()
# no argument is passed in function definition, as in function prototype, arguments are already padssed by default
# Out:
# >>> Plane...
#
# 	Vector Form :
# 		[ r - ( (2)i + (5)j + (-3)k ) ].[ (2) i+ (1) j+ (-2)k ] = 0
#
# 		r.[ (2) i+ (1) j+ (-2)k ] = 5
#
# 	Cartesian form :
# 		(2)(x- (2)) + (1)(y- (5)) + (-2)(z- (-3)) = 0
#
# 		(2)x + (1)y + (-2)z = 5
#
# 	Intercept form :
# 		   x/(2.500) + y/(5.000) + z/(-2.500) = 1
# >>> Plane...
#
# 	Vector Form :
# 		[ r - ( (2)i + (5)j + (-3)k ) ].[ (2) i+ (1) j+ (-2)k ] = 0
#
# 		r.[ (2) i+ (1) j+ (-2)k ] = 7
#
# 	Cartesian form :
# 		(2)(x- (2)) + (1)(y- (5)) + (-2)(z- (-3)) = 0
#
# 		(2)x + (1)y + (-2)z = 7
#
# 	Intercept form :
# 		   x/(3.500) + y/(7.000) + z/(-3.500) = 1
# >>> Planes are Parallel...
#
# 	Angle between Planes...
#
# 	r.((2)i+(1)j+(-2)k) = 5 and
# 	r.((2)i+(1)j+(-2)k) = 7 is...
#
#
# 	angle = arccos( abs( 9/9.0 ))
# 	= arccos( sqrt( 81 ) / sqrt( 81.0 ))
# 	= arccos( 1.0 )
# 	= 0.0 radian
# 	= 0.0 degree

# %%
print(angle, type(angle))
# Out:
# 0.0 <class 'numpy.float64'>

# %% [markdown]
# # 3D line

# %%
# solved example = 6, pg. no. = 469, from NCERT book

l = vix.line(a=[5,2,-4], b=[3,2,-8])
# Out:
# >>> Line...
#
# 	Vector Form :
# 		r = [ (5)i + (2)j + (-4)k ] + u*[ (3)i + (2)j + (-8)k ]
#
# 	Cartesian form :
#
# 		[x- (5)] / (2) = [y- (-4)] / (3) = [z- (2)] / (-8)

# %%
l, len(l), type(l), type(l[0])
# Out:
# ((array([ 5,  2, -4]), array([ 3,  2, -8])), 2, tuple, numpy.ndarray)

# %%
# 7, 470
vix.line(a=[-1,0,2], b=[3,4,6], two_points=True)
# Out:
# >>> Line...
#
# 	Vector Form :
# 		r = [ (-1)i + (0)j + (2)k ] + u*[ (4)i + (4)j + (4)k ]
#
# 	Cartesian form :
#
# 		[x- (-1)] / (0) = [y- (2)] / (4) = [z- (4)] / (4)
# (array([-1,  0,  2]), array([4, 4, 4]))

# %%
# 11, 476
vix.distbw2line(a1=[1,1,0], b1=[2,-1,1], a2=[2,1,-1], b2=[3,-5,2]) #show code
# Out:
# >>> Line1...
#
# 	Vector Form :
# 		r = [ (1)i + (1)j + (0)k ] + u*[ (2)i + (-1)j + (1)k ]
#
# 	Cartesian form :
#
# 		[x- (1)] / (1) = [y- (0)] / (2) = [z- (-1)] / (1)
# >>> Line2...
#
# 	Vector Form :
# 		r = [ (2)i + (1)j + (-1)k ] + u*[ (3)i + (-5)j + (2)k ]
#
# 	Cartesian form :
#
# 		[x- (2)] / (1) = [y- (-1)] / (3) = [z- (-5)] / (2)
# >>> Lines are [ NOT ] Parallel...
#
# 	Distance between Lines...
#
# 	r = (1)i+(1)j+(0)k + l((2)i+(-1)j+(1)k) and
# 	r = (2)i+(1)j+(-1)k + u((3)i+(-5)j+(2)k) is...
#
#
# 	distance = sqrt( 100 ) / sqrt( 58.99999999999999 )
# 	= 10/7.681145747868608
# 	= 1.3018891098082388 units.
# 1.3018891098082388

# %%
# 12, 476
vix.distbw2line(a1=[1,2,-4], b1=[2,3,6], a2=[3,3,-5], b2=[2,3,6]) # b1==b2
# Out:
# >>> Line1...
#
# 	Vector Form :
# 		r = [ (1)i + (2)j + (-4)k ] + u*[ (2)i + (3)j + (6)k ]
#
# 	Cartesian form :
#
# 		[x- (1)] / (2) = [y- (-4)] / (2) = [z- (3)] / (6)
# >>> Line2...
#
# 	Vector Form :
# 		r = [ (3)i + (3)j + (-5)k ] + u*[ (2)i + (3)j + (6)k ]
#
# 	Cartesian form :
#
# 		[x- (3)] / (3) = [y- (-5)] / (2) = [z- (3)] / (6)
# >>> Lines are Parallel...
#
# 	Distance between Lines...
#
# 	r = (1)i+(2)j+(-4)k + l((2)i+(3)j+(6)k) and
# 	r = (3)i+(3)j+(-5)k + u((2)i+(3)j+(6)k) is...
#
#
# 	distance = sqrt( 293.0 ) / sqrt( 49.0 )
# 	= 17.11724276862369/7.0
# 	= 2.44532039551767 units.
# 2.44532039551767

# %% [markdown]
# # plane

# %%
# 15, 481
vix.distbwpointandplane(a=[0,0,0], n=[2,-3,4], d=6) # a is origin point
# Out:
# >>> Plane...
#
# 	Vector Form :
# 		[ r - ( (2)i + (5)j + (-3)k ) ].[ (2) i+ (-3) j+ (4)k ] = 0
#
# 		r.[ (2) i+ (-3) j+ (4)k ] = 6
#
# 	Cartesian form :
# 		(2)(x- (2)) + (-3)(y- (5)) + (4)(z- (-3)) = 0
#
# 		(2)x + (-3)y + (4)z = 6
#
# 	Intercept form :
# 		   x/(3.000) + y/(-2.000) + z/(1.500) = 1
# >>> Distance between :
#
# 	Plane...
# 	r.((2)i+(-3)j+(4)k) = 6
#
# 	and, Point (0,0,0) is...
# 	= sqrt( 36 ) / sqrt( 28.999999999999996 )
# 	= 6 / 5.385164807134504
# 	= 1.1141720290623112 units.
# 1.1141720290623112

# %%
# 17, 483
vix.plane(a=[5,2,-4], n=[2,3,-1])
# Out:
# >>> Plane...
#
# 	Vector Form :
# 		[ r - ( (5)i + (2)j + (-4)k ) ].[ (2) i+ (3) j+ (-1)k ] = 0
#
# 		r.[ (2) i+ (3) j+ (-1)k ] = 20
#
# 	Cartesian form :
# 		(2)(x- (5)) + (3)(y- (2)) + (-1)(z- (-4)) = 0
#
# 		(2)x + (3)y + (-1)z = 20
#
# 	Intercept form :
# 		   x/(10.000) + y/(6.667) + z/(-20.000) = 1
# (array([ 5,  2, -4]), array([ 2,  3, -1]), 20)

# %%
# 18, 484
vix.plane(a=[2,5,-3], n=[-2,-3,5], p=[5,3,-3], three_points = True)
# Out:
# >>> Plane...
#
# 	Vector Form :
# 		[ r - ( (2)i + (5)j + (-3)k ) ].[ (16) i+ (24) j+ (32)k ] = 0
#
# 		r.[ (16) i+ (24) j+ (32)k ] = 56
#
# 	Cartesian form :
# 		(16)(x- (2)) + (24)(y- (5)) + (32)(z- (-3)) = 0
#
# 		(16)x + (24)y + (32)z = 56
#
# 	Intercept form :
# 		   x/(3.500) + y/(2.333) + z/(1.750) = 1
# (array([ 2,  5, -3]), array([16, 24, 32]), 56)

# %%
# 21, 488
vix.coplanof2line(a1=[-3, 1,5], b1=[-3,1,5], a2=[-1,2,5], b2=[-1,2,5])

# if np.dot((a2-a1), np.cross(b1, b2)) == 0: # ...show in book.
#     print('\t...Coplanar.')
# Out:
# >>> Line1...
#
# 	Vector Form :
# 		r = [ (-3)i + (1)j + (5)k ] + u*[ (-3)i + (1)j + (5)k ]
#
# 	Cartesian form :
#
# 		[x- (-3)] / (1) = [y- (5)] / (-3) = [z- (1)] / (5)
# >>> Line2...
#
# 	Vector Form :
# 		r = [ (-1)i + (2)j + (5)k ] + u*[ (-1)i + (2)j + (5)k ]
#
# 	Cartesian form :
#
# 		[x- (-1)] / (2) = [y- (5)] / (-1) = [z- (2)] / (5)
# >>> Lines...
#
# 	r = (-3)i+(1)j+(5)k + l((-3)i+(1)j+(5)k) and
# 	r = (-1)i+(2)j+(5)k + u((-1)i+(2)j+(5)k) is...
#
# 	...Coplanar.
# True

# %%
# 22, 489
vix.angbw2plane(n1=[2,1,-2], d1=5, n2=[3,-6,-2], d2=7)
# Out:
# >>> Plane...
#
# 	Vector Form :
# 		[ r - ( (2)i + (5)j + (-3)k ) ].[ (2) i+ (1) j+ (-2)k ] = 0
#
# 		r.[ (2) i+ (1) j+ (-2)k ] = 5
#
# 	Cartesian form :
# 		(2)(x- (2)) + (1)(y- (5)) + (-2)(z- (-3)) = 0
#
# 		(2)x + (1)y + (-2)z = 5
#
# 	Intercept form :
# 		   x/(2.500) + y/(5.000) + z/(-2.500) = 1
# >>> Plane...
#
# 	Vector Form :
# 		[ r - ( (2)i + (5)j + (-3)k ) ].[ (3) i+ (-6) j+ (-2)k ] = 0
#
# 		r.[ (3) i+ (-6) j+ (-2)k ] = 7
#
# 	Cartesian form :
# 		(3)(x- (2)) + (-6)(y- (5)) + (-2)(z- (-3)) = 0
#
# 		(3)x + (-6)y + (-2)z = 7
#
# 	Intercept form :
# 		   x/(2.333) + y/(-1.167) + z/(-3.500) = 1
# >>> Planes are [ NOT ] Parallel...
#
# 	Angle between Planes...
#
# 	r.((2)i+(1)j+(-2)k) = 5 and
# 	r.((3)i+(-6)j+(-2)k) = 7 is...
#
#
# 	angle = arccos( abs( 4/21.0 ))
# 	= arccos( sqrt( 16 ) / sqrt( 441.0 ))
# 	= arccos( 0.19047619047619047 )
# 	= 1.3791491318194802 radian
# 	= 79.01972865672893 degree
# 79.01972865672893

# %%
# 24, 491
vix.distbwpointandplane(a=[2,5,-3], n=[6,-3,2], d=4)
# Out:
# >>> Plane...
#
# 	Vector Form :
# 		[ r - ( (2)i + (5)j + (-3)k ) ].[ (6) i+ (-3) j+ (2)k ] = 0
#
# 		r.[ (6) i+ (-3) j+ (2)k ] = 4
#
# 	Cartesian form :
# 		(6)(x- (2)) + (-3)(y- (5)) + (2)(z- (-3)) = 0
#
# 		(6)x + (-3)y + (2)z = 4
#
# 	Intercept form :
# 		   x/(0.667) + y/(-1.333) + z/(2.000) = 1
# >>> Distance between :
#
# 	Plane...
# 	r.((6)i+(-3)j+(2)k) = 4
#
# 	and, Point (2,5,-3) is...
# 	= sqrt( 169 ) / sqrt( 49.0 )
# 	= 13 / 7.0
# 	= 1.8571428571428572 units.
# 1.8571428571428572

# %%
# 25, 492
vix.angbwlineandplane(a=[-1,0,3], b=[2,3,6], n=[10,2,-11], d=3)
# Out:
# >>> Line...
#
# 	Vector Form :
# 		r = [ (-1)i + (0)j + (3)k ] + u*[ (2)i + (3)j + (6)k ]
#
# 	Cartesian form :
#
# 		[x- (-1)] / (0) = [y- (3)] / (2) = [z- (3)] / (6)
# >>> Plane...
#
# 	Vector Form :
# 		[ r - ( (2)i + (5)j + (-3)k ) ].[ (10) i+ (2) j+ (-11)k ] = 0
#
# 		r.[ (10) i+ (2) j+ (-11)k ] = 3
#
# 	Cartesian form :
# 		(10)(x- (2)) + (2)(y- (5)) + (-11)(z- (-3)) = 0
#
# 		(10)x + (2)y + (-11)z = 3
#
# 	Intercept form :
# 		   x/(0.300) + y/(1.500) + z/(-0.273) = 1
# >>> Angle between :
#
# 	Line...
# 	r = (-1)i+(0)j+(3)k + u((2)i+(3)j+(6)k)
#
# 	and, Plane...
# 	r.((10)i+(2)j+(-11)k) = 3 is...
#
#
# 	angle = arcsin( abs( -40/105.0 ))
# 	= arcsin( sqrt( 1600 ) / sqrt( 11025.0 ))
# 	= arcsin( 0.38095238095238093 )
# 	= 0.39082613057544163 radian
# 	= 22.392773977450503 degree
# 22.392773977450503

# %% [markdown]
# # ...thanks for enjoying presentation !!!
