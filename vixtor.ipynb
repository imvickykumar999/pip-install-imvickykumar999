# %% [markdown]
# ### >>> pip install vixtor : Expained each function with unique argument set !!! ...enjoy learning ;)

# %%
import numpy as np, math
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
def mod(vector=[2,1,2]):
    return np.sqrt(sum(pow(element, 2) for element in vector))

# %%
print( mod( vector=[6,2,1] ) )

mod
# Out:
# 6.4031242374328485
# <function __main__.mod(vector=[2, 1, 2])>

# %%
mod()
# Out:
# 3.0

# %%
def showplane(n=[1, 1, 2]):

    point  = np.array([1, 2, 3])
    normal = np.array(n)

    d = -point.dot(normal)
    xx, yy = np.meshgrid(range(10), range(10))
    z = (-normal[0] * xx - normal[1] * yy - d) * 1. /normal[2]

    plt3d = plt.figure().gca(projection='3d')
    plt3d.plot_surface(xx, yy, z)
    plt.show()

# %%
showplane()

# %%
print( showplane )

type(showplane)
# Out:
# <function showplane at 0x0000021A902A3C10>
# function

# %%
showplane(n=[7,3,1])

# %%
def showline(a=[-1,0,2], 
             b=[4,4,4], 
             u=10):

    a = np.array(a)
    b = np.array(b)
    
    r = a + u*b # different value of 'u' give different 'r' points on line
    
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    ax.plot(xs=[a[0], r[0]], ys=[a[1], r[1]], zs=[a[2], r[2]])
    plt.show()
    # Axes3D.plot()

# %%
showline(a=[-1,0,2], b=[4,4,4], u=1)

# %%
showline(a=[1,2,5], b=[7,8,2])

# %%
def line(a=[1,2,-4], 
         b=[2,3,6],
         two_points = False, 
         sno='',
         printing = False):

    r = np.array([a, b])
    a = np.array(r[0])
    b = np.array(r[1])

    if two_points == True:
        b = b-a

    if printing == True:
        
        print('''
    >>> Line{}...

        Vector Form :
            r = [ ({})i + ({})j + ({})k ] + u*[ ({})i + ({})j + ({})k ]

        Cartesian form :

            [x- ({})] / ({}) = [y- ({})] / ({}) = [z- ({})] / ({})
        '''.format(sno, a[0], a[1], a[2], b[0], b[1], b[2], a[0], a[1], a[2],
        b[0], b[1], b[2]))

        showline(a, b, u=10)

    return a, b

# %%
line(a=[1,2,-4], b=[2,3,6], two_points = False, sno='', printing = True)
# Out:
#     >>> Line...
#
#         Vector Form :
#             r = [ (1)i + (2)j + (-4)k ] + u*[ (2)i + (3)j + (6)k ]
#
#         Cartesian form :
#
#             [x- (1)] / (2) = [y- (-4)] / (2) = [z- (3)] / (6)
# (array([ 1,  2, -4]), array([2, 3, 6]))

# %%
line(a=[-1,0,2], b=[3,4,6], two_points = True, printing = False)
# Out:
# (array([-1,  0,  2]), array([4, 4, 4]))

# %%
return_line = line(a=[2,1,-1], b=[3,-5,2], two_points = False)

print( return_line[1] )
print( type( return_line[0] ))

return_line
# Out:
# [ 3 -5  2]
# <class 'numpy.ndarray'>
# (array([ 2,  1, -1]), array([ 3, -5,  2]))

# %%
line(a=[1,1,0], b=[2,-1,1], printing = True)
# Out:
#     >>> Line...
#
#         Vector Form :
#             r = [ (1)i + (1)j + (0)k ] + u*[ (2)i + (-1)j + (1)k ]
#
#         Cartesian form :
#
#             [x- (1)] / (1) = [y- (0)] / (2) = [z- (-1)] / (1)
# (array([1, 1, 0]), array([ 2, -1,  1]))

# %%
# ...couldn't solve question 20, pg- 486 in class 11 NCERT book !!!

def plane(a=[2,5,-3],
          n=[-2,-3,5],
          p=[5,3,-3],
          dis=34,
          nd = False,
          three_points = False,
          sno='', 
          printing = False):

    r = np.array([a, n])
    a = np.array(r[0])
    n = np.array(r[1])
    p = np.array(p)

    if three_points == True:
        n = np.cross(n-a, p-a)

    d = n[0]*a[0] + n[1]*a[1] + n[2]*a[2]

    if nd == True:
        d = dis

    if d<0:
        n, d = -n, -d

    if printing == True:
        
        print('''
    >>> Plane...

        Vector Form :
            [ r - ( ({})i + ({})j + ({})k ) ].[ ({}) i+ ({}) j+ ({})k ] = 0

            r.[ ({}) i+ ({}) j+ ({})k ] = {}

        Cartesian form :
            ({})(x- ({})) + ({})(y- ({})) + ({})(z- ({})) = 0

            ({})x + ({})y + ({})z = {}

        Intercept form :
               x/({:.3f}) + y/({:.3f}) + z/({:.3f}) = 1
        '''.format(
        a[0], a[1], a[2], n[0], n[1], n[2], n[0], n[1], n[2], d,
        n[0], a[0], n[1], a[1], n[2], a[2], n[0], n[1], n[2], d,
        d/n[0], d/n[1], d/n[2]))

        showplane(n=n)

    return a, n, d

# %%
plane(a=[1,1,1], n=[1,2,0], p = [-1,2,1], three_points = True)
# Out:
# (array([1, 1, 1]), array([1, 2, 2]), 5)

# %%
plane(a=[5,2,-4], n=[2,3,-1], printing = True)
# Out:
#     >>> Plane...
#
#         Vector Form :
#             [ r - ( (5)i + (2)j + (-4)k ) ].[ (2) i+ (3) j+ (-1)k ] = 0
#
#             r.[ (2) i+ (3) j+ (-1)k ] = 20
#
#         Cartesian form :
#             (2)(x- (5)) + (3)(y- (2)) + (-1)(z- (-4)) = 0
#
#             (2)x + (3)y + (-1)z = 20
#
#         Intercept form :
#                x/(10.000) + y/(6.667) + z/(-20.000) = 1
# (array([ 5,  2, -4]), array([ 2,  3, -1]), 20)

# %%
plane(n=[2,3,4], dis = -5, nd = True, printing = True)
# Out:
#     >>> Plane...
#
#         Vector Form :
#             [ r - ( (2)i + (5)j + (-3)k ) ].[ (-2) i+ (-3) j+ (-4)k ] = 0
#
#             r.[ (-2) i+ (-3) j+ (-4)k ] = 5
#
#         Cartesian form :
#             (-2)(x- (2)) + (-3)(y- (5)) + (-4)(z- (-3)) = 0
#
#             (-2)x + (-3)y + (-4)z = 5
#
#         Intercept form :
#                x/(-2.500) + y/(-1.667) + z/(-1.250) = 1
# (array([ 2,  5, -3]), array([-2, -3, -4]), 5)

# %%
plane(three_points = True, printing = False)
# Out:
# (array([ 2,  5, -3]), array([16, 24, 32]), 56)

# %%
return_plane = plane() # default argument in plane()'s function prototype is used as no argument is passed !!!

return_plane
# Out:
# (array([ 2,  5, -3]), array([ 2,  3, -5]), 34)

# %%
plane(a=[2,5,-3], n=[-2,-3,5], p=[5,3,-3], dis=34, nd = False, three_points = False, sno='')
# Out:
# (array([ 2,  5, -3]), array([ 2,  3, -5]), 34)

# %%
plane

# printing function prototype of plane() function.
# Out:
# <function __main__.plane(a=[2, 5, -3], n=[-2, -3, 5], p=[5, 3, -3], dis=34, nd=False, three_points=False, sno='', printing=False)>

# %%
plane(printing = True)
# Out:
#     >>> Plane...
#
#         Vector Form :
#             [ r - ( (2)i + (5)j + (-3)k ) ].[ (2) i+ (3) j+ (-5)k ] = 0
#
#             r.[ (2) i+ (3) j+ (-5)k ] = 34
#
#         Cartesian form :
#             (2)(x- (2)) + (3)(y- (5)) + (-5)(z- (-3)) = 0
#
#             (2)x + (3)y + (-5)z = 34
#
#         Intercept form :
#                x/(17.000) + y/(11.333) + z/(-6.800) = 1
# (array([ 2,  5, -3]), array([ 2,  3, -5]), 34)

# %%
def comp_hcf(x=15, y=80):

    x, y = int(x), int(y)
    if x > y:
        s = y
    else:
        s = x

    for i in range(1, s+1):
        if((x % i == 0) and (y % i == 0)):
            hcf = i

#     print(hcf)
    return hcf

# %%
comp_hcf(x=15, y=80)
# Out:
# 5

# %%
'''
Ques. How do you ( reduce fractions ) step by step?

>>> Here are the steps to follow:
    
    1. Write down the factors for the numerator and the denominator.
    2. Determine the largest factor that is common between the two.
    3. Divide the numerator and denominator by the greatest common factor.
    4. Write down the reduced fraction.
'''

print('Target is to write ( 52 / 130 ) in reduced form using comp_hcf() user-defined function')

no1, no2 = 52, 130

hcf = comp_hcf(no1, no2)

print('\n\t HCF of {} and {} is {}'.format(no1, no2, hcf), end = '\n>>> ')
print('Divide {} and {} with {}, we get {} and {}'. format(no1, no2, hcf, int(no1/hcf), int(no2/hcf)))

no1 /= hcf # [ number1 = number1 / hcf ], ...shorthand method ( /= )
no2 /= hcf

'{} / {}'.format(no1, no2)
# Out:
# Target is to write ( 52 / 130 ) in reduced form using comp_hcf() user-defined function
#
# 	 HCF of 52 and 130 is 26
# >>> Divide 52 and 130 with 26, we get 2 and 5
# '2.0 / 5.0'

# %%
def angbw2line(a1=[3,2,-4], 
               b1=[1,2,2],
               a2=[5,-2,0], 
               b2=[3,2,6], 
               printing = False):

    a1, b1 = line(a1, b1, sno=1, printing = printing)
    a2, b2 = line(a2, b2, sno=2, printing = printing)

    h = np.dot(b1, b2)
    k = mod(b1)*mod(b2)

    cos = abs(h/k)
    arc = np.arccos(cos)
    deg = arc*57.296

    if printing == True:
        
        print('''
    >>> Angle between :

        Line1...
        r = ({})i+({})j+({})k + u(({})i+({})j+({})k)

        and, Line2...
        r = ({})i+({})j+({})k + u(({})i+({})j+({})k) is...
        '''.format(a1[0], a1[1], a1[2], b1[0], b1[1], b1[2], 
                   a2[0], a2[1], a2[2], b2[0], b2[1], b2[2]))

        print('''
        angle = arccos( abs( {}/{} ))
        = arccos( sqrt( {} ) / sqrt( {} ))
        = arccos( {} )
        = {} radian
        = {} degree'''.format(h, k, h*h, k*k, cos, arc, deg))

    return deg

# %%
angbw2line(a1=[2,5,-3], 
               b1=[3,5,1],
               a2=[6,-3,2], 
               b2=[4,8,9], 
               printing = False)
# Out:
# 35.64828117496806

# %%
angbw2line( printing = True )
# Out:
#     >>> Line1...
#
#         Vector Form :
#             r = [ (3)i + (2)j + (-4)k ] + u*[ (1)i + (2)j + (2)k ]
#
#         Cartesian form :
#
#             [x- (3)] / (2) = [y- (-4)] / (1) = [z- (2)] / (2)
#     >>> Line2...
#
#         Vector Form :
#             r = [ (5)i + (-2)j + (0)k ] + u*[ (3)i + (2)j + (6)k ]
#
#         Cartesian form :
#
#             [x- (5)] / (-2) = [y- (0)] / (3) = [z- (2)] / (6)
#     >>> Angle between :
#
#         Line1...
#         r = (3)i+(2)j+(-4)k + u((1)i+(2)j+(2)k)
#
#         and, Line2...
#         r = (5)i+(-2)j+(0)k + u((3)i+(2)j+(6)k) is...
#
#
#         angle = arccos( abs( 19/21.0 ))
#         = arccos( sqrt( 361 ) / sqrt( 441.0 ))
#         = arccos( 0.9047619047619048 )
#         = 0.4399759547909189 radian
#         = 25.20886230570049 degree
# 25.20886230570049

# %%
angbw2line()
# Out:
# 25.20886230570049

# %%
def distbw2line(a1=[1,2,-4], 
                b1=[2,3,6],
                a2=[3,3,-5], 
                b2=[2,3,6], 
                printing = False):

    a1, b1 = line(a1, b1, sno=1, printing = printing)
    a2, b2 = line(a2, b2, sno=2, printing = printing)

    r2 = np.array([a2, b2])
    a2 = np.array(r2[0])
    b2 = np.array(r2[1])

    c = np.cross(b1, b2)

    if (b1 == b2).all():
        c = b1
        e = mod(np.cross(c, a2-a1))
        l = "\n>>> Lines are Parallel..."
    else:
        e = np.dot(c, a2-a1)
        l = "\n>>> Lines are [ NOT ] Parallel..."

    e = abs(e)
    c = mod(c)

    if printing == True:
        print('''
        {}
        
        Distance between Lines...

        r = ({})i+({})j+({})k + l(({})i+({})j+({})k) and
        r = ({})i+({})j+({})k + u(({})i+({})j+({})k) is...
        '''.format(l, a1[0], a1[1], a1[2], b1[0], b1[1], b1[2], 
                   a2[0], a2[1], a2[2], b2[0], b2[1], b2[2]))

        print('''
        distance = sqrt( {} ) / sqrt( {} )
        = {}/{}
        = {} units.'''.format(e*e, c*c, e, c, e/c))

    return e/c

# %%
print( distbw2line(a1=[1,2,-4], b1=[2,3,6], a2=[3,3,-5], b2=[2,3,6]) )
# Out:
# 2.44532039551767

# %%
distbw2line()
# Out:
# 2.44532039551767

# %%
distbw2line( printing = True )
# Out:
#     >>> Line1...
#
#         Vector Form :
#             r = [ (1)i + (2)j + (-4)k ] + u*[ (2)i + (3)j + (6)k ]
#
#         Cartesian form :
#
#             [x- (1)] / (2) = [y- (-4)] / (2) = [z- (3)] / (6)
#     >>> Line2...
#
#         Vector Form :
#             r = [ (3)i + (3)j + (-5)k ] + u*[ (2)i + (3)j + (6)k ]
#
#         Cartesian form :
#
#             [x- (3)] / (3) = [y- (-5)] / (2) = [z- (3)] / (6)
#
# >>> Lines are Parallel...
#
#         Distance between Lines...
#
#         r = (1)i+(2)j+(-4)k + l((2)i+(3)j+(6)k) and
#         r = (3)i+(3)j+(-5)k + u((2)i+(3)j+(6)k) is...
#
#
#         distance = sqrt( 293.0 ) / sqrt( 49.0 )
#         = 17.11724276862369/7.0
#         = 2.44532039551767 units.
# 2.44532039551767

# %%
error = '''
>>>> if you run it,

print( distbw2line(a1 = [1,1,0], [2,-1,1], a2 = [2,1,-1], printing = False, b2 = [3,-5,2]))

>>> output error will be :

File "<ipython-input-183-d7c9588fe1e2>", line 1
    print( distbw2line(a1 = [1,1,0], [2,-1,1], a2 = [2,1,-1], printing = False, b2 = [3,-5,2]))
                                    ^
SyntaxError: positional argument follows keyword argument
'''

print( distbw2line([1,1,0], [2,-1,1], a2 = [2,1,-1], printing = False, b2 = [3,-5,2]))

distbw2line
# Out:
# 1.3018891098082388
# <function __main__.distbw2line(a1=[1, 2, -4], b1=[2, 3, 6], a2=[3, 3, -5], b2=[2, 3, 6], printing=False)>

# %%
print(error) # due to positional arguments, default argument must pass in starting parameter not at last.
# Out:
# >>>> if you run it,
#
# print( distbw2line(a1 = [1,1,0], [2,-1,1], a2 = [2,1,-1], printing = False, b2 = [3,-5,2]))
#
# >>> output error will be :
#
# File "<ipython-input-183-d7c9588fe1e2>", line 1
#     print( distbw2line(a1 = [1,1,0], [2,-1,1], a2 = [2,1,-1], printing = False, b2 = [3,-5,2]))
#                                     ^
# SyntaxError: positional argument follows keyword argument

# %%
def coplanof2line(a1=[-3, 1,5],
                  b1=[-3,1,5], 
                  a2=[-1,2,5],
                  b2=[-1,2,5], 
                  printing = False):

    a1, b1 = line(a1, b1, sno=1, printing = printing)
    a2, b2 = line(a2, b2, sno=2, printing = printing)
    
    if np.dot((a2 - a1), np.cross(b1, b2)) == 0:
        pri = '...Coplanar.'
        ret = True
    else:
        pri = '...[ NOT ] Coplanar.'
        ret = False
    
    if printing == True:
        
        print('''
    >>> Lines...

        r = ({})i+({})j+({})k + l(({})i+({})j+({})k) and
        r = ({})i+({})j+({})k + u(({})i+({})j+({})k) is {}
        '''.format(a1[0], a1[1], a1[2], b1[0], b1[1], b1[2], 
                   a2[0], a2[1], a2[2], b2[0], b2[1], b2[2], pri))

    return ret

# %%
print( coplanof2line(a1=[7,2,4], b1=[-8,1,-5], a2=[12,5,8], b2=[-1,-8,2]) )
# Out:
# False

# %%
print( coplanof2line() )

coplanof2line
# Out:
# True
# <function __main__.coplanof2line(a1=[-3, 1, 5], b1=[-3, 1, 5], a2=[-1, 2, 5], b2=[-1, 2, 5], printing=False)>

# %%
coplanof2line( printing=False )
# Out:
# True

# %%
coplanof2line(a1=[7,2,4],
              b1=[-8,1,-5], 
              a2=[12,5,8],
              b2=[-1,-8,2],
              printing = True
             )
# Out:
#     >>> Line1...
#
#         Vector Form :
#             r = [ (7)i + (2)j + (4)k ] + u*[ (-8)i + (1)j + (-5)k ]
#
#         Cartesian form :
#
#             [x- (7)] / (2) = [y- (4)] / (-8) = [z- (1)] / (-5)
#     >>> Line2...
#
#         Vector Form :
#             r = [ (12)i + (5)j + (8)k ] + u*[ (-1)i + (-8)j + (2)k ]
#
#         Cartesian form :
#
#             [x- (12)] / (5) = [y- (8)] / (-1) = [z- (-8)] / (2)
#     >>> Lines...
#
#         r = (7)i+(2)j+(4)k + l((-8)i+(1)j+(-5)k) and
#         r = (12)i+(5)j+(8)k + u((-1)i+(-8)j+(2)k) is ...[ NOT ] Coplanar.
# False

# %%
# press ( Shift + Enter ) to run and move to 
# next cell, while ( Shift + Ctrl ) to run and stay on same cell.

def angbw2plane(n1=[3,-6,2], 
                d1=7, 
                n2=[2,1,-2], 
                d2=5, 
                printing = False):

    n1 = plane(n=n1, dis = d1, nd = True, 
               sno=1, printing = printing)[1]
    
    n2 = plane(n=n2, dis = d2, nd = True, sno=2, printing = printing)[1]

    a = np.dot(n1, n2)
    b = mod(n1)*mod(n2)

    cos = abs(a/b)
    arc = np.arccos(cos)
    deg = arc*57.296

    if deg == 0.0:
        p = "\n>>> Planes are Parallel..."
    else:
        p = "\n>>> Planes are [ NOT ] Parallel..."

    if printing == True:
        
        print('''
        {}

        Angle between Planes...

        r.(({})i+({})j+({})k) = {} and
        r.(({})i+({})j+({})k) = {} is...
        '''.format(p, n1[0], n1[1], n1[2], d1,
                   n2[0], n2[1], n2[2], d2))

        print('''
        angle = arccos( abs( {}/{} ))
        = arccos( sqrt( {} ) / sqrt( {} ))
        = arccos( {} )
        = {} radian
        = {} degree'''.format(a, b, a*a, b*b, cos, arc, deg))

    return deg

# %%
angle = angbw2plane(n1=[2,1,-2], d1=5, n2=[2,1,-2], d2=7)

print('angle = ', angle, 'degree')

angbw2plane
# click on function, variable or string's name and press ( Shift + Tab ) for detailed function's parameter.
# Out:
# angle =  0.0 degree
# <function __main__.angbw2plane(n1=[3, -6, 2], d1=7, n2=[2, 1, -2], d2=5, printing=False)>

# %%
angbw2plane(printing = True)
# Out:
#     >>> Plane...
#
#         Vector Form :
#             [ r - ( (2)i + (5)j + (-3)k ) ].[ (3) i+ (-6) j+ (2)k ] = 0
#
#             r.[ (3) i+ (-6) j+ (2)k ] = 7
#
#         Cartesian form :
#             (3)(x- (2)) + (-6)(y- (5)) + (2)(z- (-3)) = 0
#
#             (3)x + (-6)y + (2)z = 7
#
#         Intercept form :
#                x/(2.333) + y/(-1.167) + z/(3.500) = 1
#     >>> Plane...
#
#         Vector Form :
#             [ r - ( (2)i + (5)j + (-3)k ) ].[ (2) i+ (1) j+ (-2)k ] = 0
#
#             r.[ (2) i+ (1) j+ (-2)k ] = 5
#
#         Cartesian form :
#             (2)(x- (2)) + (1)(y- (5)) + (-2)(z- (-3)) = 0
#
#             (2)x + (1)y + (-2)z = 5
#
#         Intercept form :
#                x/(2.500) + y/(5.000) + z/(-2.500) = 1
#
# >>> Planes are [ NOT ] Parallel...
#
#         Angle between Planes...
#
#         r.((3)i+(-6)j+(2)k) = 7 and
#         r.((2)i+(1)j+(-2)k) = 5 is...
#
#
#         angle = arccos( abs( -4/21.0 ))
# ...

# %%
def distbwpointandplane(a=[2,5,-3],
                        n=[6,-3,2],
                        d=4,
                        printing = False):

    a = np.array(a) # here, a is point
    n = plane(n=n, dis = d, nd = True,
              printing = printing)[1]

    dot = np.dot(a, n)
    h = abs(dot-d)
    k = mod(n)
    dist = h/k

    if printing == True:
        
        print('''
    >>> Distance between :

        Plane...
        r.(({})i+({})j+({})k) = {}

        and, Point ({},{},{}) is...
        = sqrt( {} ) / sqrt( {} )
        = {} / {}
        = {} units.'''.format(n[0], n[1], n[2], d, a[0], 
                              a[1], a[2], h*h, k*k, h, k, dist))

    return dist

# %%
distbwpointandplane(a=[2,5,-3], n=[6,-3,2], d=4)
# Out:
# 1.8571428571428572

# %%
distbwpointandplane(printing=True) # default function's prototype's argument is used.
# Out:
#     >>> Plane...
#
#         Vector Form :
#             [ r - ( (2)i + (5)j + (-3)k ) ].[ (6) i+ (-3) j+ (2)k ] = 0
#
#             r.[ (6) i+ (-3) j+ (2)k ] = 4
#
#         Cartesian form :
#             (6)(x- (2)) + (-3)(y- (5)) + (2)(z- (-3)) = 0
#
#             (6)x + (-3)y + (2)z = 4
#
#         Intercept form :
#                x/(0.667) + y/(-1.333) + z/(2.000) = 1
#     >>> Distance between :
#
#         Plane...
#         r.((6)i+(-3)j+(2)k) = 4
#
#         and, Point (2,5,-3) is...
#         = sqrt( 169 ) / sqrt( 49.0 )
#         = 13 / 7.0
#         = 1.8571428571428572 units.
# 1.8571428571428572

# %%
def angbwlineandplane(a=[2,5,-3],
                      b=[3,5,1], 
                      n=[6,-3,2],
                      d=4, 
                      printing = False):

    a, b = line(a, b, printing = printing)
    
    n = plane(n=n, dis = d, nd = True,
              printing = printing)[1]

    h = np.dot(b, n)
    k = mod(b)*mod(n)

    sin = abs(h/k)
    arc = np.arcsin(sin)
    deg = arc*57.296

    if printing == True:
        
        print('''
    >>> Angle between :

        Line...
        r = ({})i+({})j+({})k + u(({})i+({})j+({})k)

        and, Plane...
        r.(({})i+({})j+({})k) = {} is...
        '''.format(a[0], a[1], a[2], b[0], b[1], b[2], n[0], n[1], n[2], d))

        print('''
        angle = arcsin( abs( {}/{} ))
        = arcsin( sqrt( {} ) / sqrt( {} ))
        = arcsin( {} )
        = {} radian
        = {} degree'''.format(h, k, h*h, k*k, sin, arc, deg))

    return deg

# %%
angbwlineandplane()
# Out:
# 6.934626398155373

# %%
angbwlineandplane(a=[2,5,-3], b=[3,5,1], n=[6,-3,2], d=4, printing = True)
# Out:
#     >>> Line...
#
#         Vector Form :
#             r = [ (2)i + (5)j + (-3)k ] + u*[ (3)i + (5)j + (1)k ]
#
#         Cartesian form :
#
#             [x- (2)] / (5) = [y- (-3)] / (3) = [z- (5)] / (1)
#     >>> Plane...
#
#         Vector Form :
#             [ r - ( (2)i + (5)j + (-3)k ) ].[ (6) i+ (-3) j+ (2)k ] = 0
#
#             r.[ (6) i+ (-3) j+ (2)k ] = 4
#
#         Cartesian form :
#             (6)(x- (2)) + (-3)(y- (5)) + (2)(z- (-3)) = 0
#
#             (6)x + (-3)y + (2)z = 4
#
#         Intercept form :
#                x/(0.667) + y/(-1.333) + z/(2.000) = 1
#     >>> Angle between :
#
#         Line...
#         r = (2)i+(5)j+(-3)k + u((3)i+(5)j+(1)k)
#
#         and, Plane...
#         r.((6)i+(-3)j+(2)k) = 4 is...
#
#
#         angle = arcsin( abs( 5/41.41255848169731 ))
#         = arcsin( sqrt( 25 ) / sqrt( 1714.9999999999998 ))
#         = arcsin( 0.1207363221040738 )
#         = 0.12103159728698991 radian
#         = 6.934626398155373 degree
# ...

# %% [markdown]
# # ...hope you enjoyed learning ;)

# %% [markdown]
# ## summary time...

# %%
mod,
showline,
showplane,
line,
plane,
comp_hcf,
angbw2line,
distbw2line,
coplanof2line,
angbw2plane,
distbwpointandplane,
angbwlineandplane
# Out:
# (<function __main__.mod(vector=[2, 1, 2])>,
#  <function __main__.showline(a=[-1, 0, 2], b=[4, 4, 4], u=10)>,
#  <function __main__.showplane(n=[1, 1, 2])>,
#  <function __main__.line(a=[1, 2, -4], b=[2, 3, 6], two_points=False, sno='', printing=False)>,
#  <function __main__.plane(a=[2, 5, -3], n=[-2, -3, 5], p=[5, 3, -3], dis=34, nd=False, three_points=False, sno='', printing=False)>,
#  <function __main__.comp_hcf(x=15, y=80)>,
#  <function __main__.angbw2line(a1=[3, 2, -4], b1=[1, 2, 2], a2=[5, -2, 0], b2=[3, 2, 6], printing=False)>,
#  <function __main__.distbw2line(a1=[1, 2, -4], b1=[2, 3, 6], a2=[3, 3, -5], b2=[2, 3, 6], printing=False)>,
#  <function __main__.coplanof2line(a1=[-3, 1, 5], b1=[-3, 1, 5], a2=[-1, 2, 5], b2=[-1, 2, 5], printing=False)>,
#  <function __main__.angbw2plane(n1=[3, -6, 2], d1=7, n2=[2, 1, -2], d2=5, printing=False)>,
#  <function __main__.distbwpointandplane(a=[2, 5, -3], n=[6, -3, 2], d=4, printing=False)>,
# ...

# %%
mod()
# Out:
# 3.0

# %%
showline()

# %%
showplane()

# %%
line()
# Out:
# (array([ 1,  2, -4]), array([2, 3, 6]))

# %%
plane()
# Out:
# (array([ 2,  5, -3]), array([ 2,  3, -5]), 34)

# %%
comp_hcf()
# Out:
# 5

# %%
angbw2line()
# Out:
# 25.20886230570049

# %%
distbw2line()
# Out:
# 2.44532039551767

# %%
coplanof2line()
# Out:
# True

# %%
angbw2plane()
# Out:
# 79.01972865672893

# %%
distbwpointandplane()
# Out:
# 1.8571428571428572

# %%
angbwlineandplane()
# Out:
# 6.934626398155373

# %% [markdown]
# # ...bye !!!
